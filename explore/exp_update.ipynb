# %%
import psycopg2
import pandas as pd
import os

# link to the database
conn = psycopg2.connect(dbname="camping", user="arrowboy")
cur = conn.cursor()

# get the list of campsites
df = pd.read_sql_query("SELECT * FROM campsites", conn)
conn.close()
df
# Out:
# /tmp/ipykernel_13330/1131202003.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM campsites", conn)
#       id                             name   latitude   longitude  \
# 0      1               Big Flat Trailhead  41.067569 -122.934103
# 1      2        Carter Meadows Campground  41.221388 -122.908594
# 2      3             East Fork Campground  41.154386 -123.107444
# 3      4             Fort Goff Campground  41.865136 -123.256153
# 4      5          Hidden Horse Campground  41.219125 -122.910840
# ..   ...                              ...        ...         ...
# 895  895               Watkins Campground  42.023630 -123.156840
# 896  896       Whiskey Springs Campground  42.492790 -122.417630
# 897  898             Willow Prairie Cabin  42.406497 -122.392563
# 898  899  Willow Prairie Horse Campground  42.406404 -122.390731
# 899  900               Wrangle Campground  42.050670 -122.855620
#
#                                                address managing_unit  \
# 0                                                 None           NaN
# 1    From Callahan, take the Callahan-Cecilville Rd...           NaN
# 2    From Callahan, take the Callahan-Cecilville ro...           NaN
# 3    From I-5, west on Hwy 96 approx. 50 miles to t...           NaN
# 4    From Callahan, take the Callahan-Cecilville Rd...           NaN
# ..                                                 ...           ...
# 895  From Ruch, OR, drive south on Upper Applegate ...          None
# 896  From Medford, OR, travel north approximately 1...          None
# 897  From Butte Falls, OR, take the Butte Falls - F...          None
# 898  From Butte Falls, OR, travel east on Road 821 ...          None
# 899  From Jacksonville, OR, travel south 6.5 miles ...          None
#
#     reservation_type                                 fs_usda_url  \
# 0               None         https://www.fs.usda.gov/r05/klamath
# 1               None         https://www.fs.usda.gov/r05/klamath
# 2               None         https://www.fs.usda.gov/r05/klamath
# 3               None         https://www.fs.usda.gov/r05/klamath
# 4               None         https://www.fs.usda.gov/r05/klamath
# ..               ...                                         ...
# 895             None  https://www.fs.usda.gov/r06/rogue-siskiyou
# 896             None  https://www.fs.usda.gov/r06/rogue-siskiyou
# 897             None  https://www.fs.usda.gov/r06/rogue-siskiyou
# 898             None  https://www.fs.usda.gov/r06/rogue-siskiyou
# 899             None  https://www.fs.usda.gov/r06/rogue-siskiyou
#
#     reservation_url contact_name contact_phone       seasons_of_use num_sites  \
# 0              None          NaN           NaN                  NaN      None
# 1              None          NaN           NaN                  NaN      None
# 2              None          NaN           NaN                  NaN      None
# 3              None          NaN           NaN                  NaN      None
# 4              None          NaN           NaN                  NaN      None
# ..              ...          ...           ...                  ...       ...
# 895            None         None          None                 None      None
# 896            None         None          None       May - November      None
# 897            None         None          None                 None      None
# 898            None         None          None  May 15 - October 31      None
# 899            None         None          None                 None      None
#
#                                                    fee overview  \
# 0           No fees are required for this site\nNo fee      NaN
# 1    Overnight Use:\nEquestrian Group Site: $50 per...      NaN
# 2           No fees are required for this site\nNo fee      NaN
# 3           No fees are required for this site\nNo fee      NaN
# 4    Overnight Use:\nEquestrian Group Site: $10 per...      NaN
# ..                                                 ...      ...
# 895  Fees apply during peak season (\nearly-May thr...      NaN
# 896  Camping:\n$16 /site/night \n\nExtra Vehiles: $...      NaN
# 897                                          $35/night      NaN
# 898  Camping: $15 /site/night \n\nExtra Vehicles: $...      NaN
# 899                                                 No      NaN
#
#                                               site_url
# 0    https://www.fs.usda.gov/r05/klamath/recreation...
# 1    https://www.fs.usda.gov/r05/klamath/recreation...
# 2    https://www.fs.usda.gov/r05/klamath/recreation...
# 3    https://www.fs.usda.gov/r05/klamath/recreation...
# 4    https://www.fs.usda.gov/r05/klamath/recreation...
# ..                                                 ...
# 895  https://www.fs.usda.gov/r06/rogue-siskiyou/rec...
# 896  https://www.fs.usda.gov/r06/rogue-siskiyou/rec...
# 897  https://www.fs.usda.gov/r06/rogue-siskiyou/rec...
# 898  https://www.fs.usda.gov/r06/rogue-siskiyou/rec...
# 899  https://www.fs.usda.gov/r06/rogue-siskiyou/rec...
#
# [900 rows x 16 columns]
